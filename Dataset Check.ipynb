# %%
import pandas as pd
import numpy as np
#importing pandas & numpy

# %%
CR7 = pd.read_csv("CR7data.csv")
#importing Cristiano Ronaldo club goals data from .csv file from Kaggle dataset.
# Chose this dataset as I'm a soccer fan & a CR7 fan.
#URL https://www.kaggle.com/datasets/azminetoushikwasi/cr7-cristiano-ronaldo-all-club-goals-stats?select=data.csv

# %%
CR7.head()
#Printing out the top few rows of the dataset to get an idea of the structure & layout
# Out:
#    Unnamed: 0  Goal_no Season                Competition      Matchday Venue  \
# 0           0        1    2/3              Liga Portugal             6     H
# 1           1        2    2/3              Liga Portugal             6     H
# 2           2        3    2/3              Liga Portugal             8     A
# 3           3        4    2/3  Ta̤a de Portugal Placard  Fourth Round     H
# 4           4        5    2/3  Ta̤a de Portugal Placard   Fifth Round     H
#
#           Team                 Opponent Result Position Minute At_score  \
# 0  Sporting CP            Moreirense FC    3:0       LW     34      2:0
# 1  Sporting CP            Moreirense FC    3:0      NaN   90+5      3:0
# 2  Sporting CP              Boavista FC    1:2      NaN     88      1:2
# 3  Sporting CP             CD Estarreja    4:1      NaN     67      3:0
# 4  Sporting CP  FC Oliveira do Hospital    8:1      NaN     13      3:0
#
#         Type_of_goal
# 0           Solo run
# 1             Header
# ...

# %%
CR7.info()
#Print out the information of the dataset. Want to see rows, columns, types of data, any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    698 non-null    int64
#  1   Goal_no       698 non-null    int64
#  2   Season        698 non-null    object
#  3   Competition   698 non-null    object
#  4   Matchday      698 non-null    object
#  5   Venue         698 non-null    object
#  6   Team          698 non-null    object
#  7   Opponent      698 non-null    object
#  8   Result        698 non-null    object
#  9   Position      640 non-null    object
#  10  Minute        698 non-null    object
#  11  At_score      698 non-null    object
#  12  Type_of_goal  683 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 71.0+ KB

# %%
# From above can see there's 698 rows & 13 columns in this dataset.
# majority of the data here is fully filled in
# just 2 columns with some null data

# %%
missing_values_count = CR7.isnull().sum()
print(missing_values_count)
# counting the number of null values and printing to the screen by column
# Out:
# Unnamed: 0       0
# Goal_no          0
# Season           0
# Competition      0
# Matchday         0
# Venue            0
# Team             0
# Opponent         0
# Result           0
# Position        58
# Minute           0
# At_score         0
# Type_of_goal    15
# dtype: int64

# %%
pd.DataFrame(requests.get('https://rapidapi.com/GiulianoCrescimbeni/api/football98/').json()).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6cb7356d0f5f> in <module>
# ----> 1 pd.DataFrame(requests.get('https://rapidapi.com/GiulianoCrescimbeni/api/football98/').json()).head()
#
# NameError: name 'requests' is not defined

# %%
import requests

# %%
pd.DataFrame(requests.get('https://rapidapi.com/GiulianoCrescimbeni/api/football98/').json()).head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-13-6cb7356d0f5f> in <module>
# ----> 1 pd.DataFrame(requests.get('https://rapidapi.com/GiulianoCrescimbeni/api/football98/').json()).head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
pd.DataFrame(requests.get('https://github.com/azharimm/football-standings-api').json()).head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-0763d0719ccb> in <module>
# ----> 1 pd.DataFrame(requests.get('https://github.com/azharimm/football-standings-api').json()).head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
google = requests.get('http://google.com')
type(google)
# Out:
# requests.models.Response

# %%
requests.get('http://google.com')
# Out:
# <Response [200]>

# %%
pd.DataFrame(requests.get('https://github.com/azharimm/football-standings-api').json()).head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-0763d0719ccb> in <module>
# ----> 1 pd.DataFrame(requests.get('https://github.com/azharimm/football-standings-api').json()).head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
google.status_code
# Out:
# 200

# %%
pd.DataFrame(requests.get('https://github.com/azharimm/football-standings-api').json()).head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-0763d0719ccb> in <module>
# ----> 1 pd.DataFrame(requests.get('https://github.com/azharimm/football-standings-api').json()).head()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
# !json
# Out:
# /bin/bash: json: command not found

# %%
iss = requests.get('http://api.open-notify.org/iss-now.json')
iss.json()
# Out:
# {'message': 'success',
#  'timestamp': 1652211289,
#  'iss_position': {'latitude': '-0.3239', 'longitude': '179.6307'}}

# %%
pd.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-df9aa9396418> in <module>
# ----> 1 pd.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
#
# NameError: name 'pd' is not defined

# %%
d.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19043ce59bc7> in <module>
# ----> 1 d.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
#
# NameError: name 'd' is not defined

# %%
pd.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-df9aa9396418> in <module>
# ----> 1 pd.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
#
# NameError: name 'requests' is not defined

# %%
import requests

# %%
pd.DataFrame(requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc').json()).head()
# Out:
#                status                                               data
# abbreviation     True                                               Prem
# name             True                             English Premier League
# season           True                                               2020
# seasonDisplay    True                                          2020-2021
# standings        True  [{'team': {'id': '382', 'uid': 's:600~t:382', ...

# %%
standings = requests.get('https://api-football-standings.azharimm.site/leagues/eng.1/standings?season=2020&sort=asc')
standings.json()
# Out:
# {'status': True,
#  'data': {'name': 'English Premier League',
#   'abbreviation': 'Prem',
#   'seasonDisplay': '2020-2021',
#   'season': 2020,
#   'standings': [{'team': {'id': '382',
#      'uid': 's:600~t:382',
#      'location': 'Manchester City',
#      'name': 'Manchester City',
#      'abbreviation': 'MNC',
#      'displayName': 'Manchester City',
#      'shortDisplayName': 'Man City',
#      'isActive': True,
#      'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#        'width': 500,
#        'height': 500,
#        'alt': '',
#        'rel': ['full', 'default'],
#        'lastUpdated': '2019-05-08T16:07Z'}]},
#     'note': {'color': '#81D6AC', 'description': 'Champions League', 'rank': 1},
#     'stats': [{'name': 'wins',
#       'displayName': 'Wins',
#       'shortDisplayName': 'W',
#       'description': "Team's current Win-Loss record",
#       'abbreviation': 'W',
#       'type': 'wins',
#       'value': 27,
#       'displayValue': '27'},
# ...

# %%
standings_DF = pd.DataFrame(standings.json())

# %%
standings_DF
# Out:
#                status                                               data
# abbreviation     True                                               Prem
# name             True                             English Premier League
# season           True                                               2020
# seasonDisplay    True                                          2020-2021
# standings        True  [{'team': {'id': '382', 'uid': 's:600~t:382', ...

# %%
standings_DF['standings']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'standings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-7206d93e1235> in <module>
# ...

# %%
standings_DF['data']['standings']
# Out:
# [{'team': {'id': '382',
#    'uid': 's:600~t:382',
#    'location': 'Manchester City',
#    'name': 'Manchester City',
#    'abbreviation': 'MNC',
#    'displayName': 'Manchester City',
#    'shortDisplayName': 'Man City',
#    'isActive': True,
#    'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'default'],
#      'lastUpdated': '2019-05-08T16:07Z'}]},
#   'note': {'color': '#81D6AC', 'description': 'Champions League', 'rank': 1},
#   'stats': [{'name': 'wins',
#     'displayName': 'Wins',
#     'shortDisplayName': 'W',
#     'description': "Team's current Win-Loss record",
#     'abbreviation': 'W',
#     'type': 'wins',
#     'value': 27,
#     'displayValue': '27'},
#    {'name': 'losses',
#     'displayName': 'Losses',
#     'shortDisplayName': 'L',
#     'description': 'Losses',
#     'abbreviation': 'L',
#     'type': 'losses',
#     'value': 6,
# ...

# %%
standings_DF['data']['name']
# Out:
# 'English Premier League'

# %%
standings_DF['data']['standings'][0]
# Out:
# {'team': {'id': '382',
#   'uid': 's:600~t:382',
#   'location': 'Manchester City',
#   'name': 'Manchester City',
#   'abbreviation': 'MNC',
#   'displayName': 'Manchester City',
#   'shortDisplayName': 'Man City',
#   'isActive': True,
#   'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#     'width': 500,
#     'height': 500,
#     'alt': '',
#     'rel': ['full', 'default'],
#     'lastUpdated': '2019-05-08T16:07Z'}]},
#  'note': {'color': '#81D6AC', 'description': 'Champions League', 'rank': 1},
#  'stats': [{'name': 'wins',
#    'displayName': 'Wins',
#    'shortDisplayName': 'W',
#    'description': "Team's current Win-Loss record",
#    'abbreviation': 'W',
#    'type': 'wins',
#    'value': 27,
#    'displayValue': '27'},
#   {'name': 'losses',
#    'displayName': 'Losses',
#    'shortDisplayName': 'L',
#    'description': 'Losses',
#    'abbreviation': 'L',
#    'type': 'losses',
#    'value': 6,
#    'displayValue': '6'},
#   {'name': 'ties',
# ...

# %%
standings_DF['data']['standings'][0]['team']
# Out:
# {'id': '382',
#  'uid': 's:600~t:382',
#  'location': 'Manchester City',
#  'name': 'Manchester City',
#  'abbreviation': 'MNC',
#  'displayName': 'Manchester City',
#  'shortDisplayName': 'Man City',
#  'isActive': True,
#  'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#    'width': 500,
#    'height': 500,
#    'alt': '',
#    'rel': ['full', 'default'],
#    'lastUpdated': '2019-05-08T16:07Z'}]}

# %%
standings_DF['data']['standings'][0]['team']['name']
# Out:
# 'Manchester City'

# %%
pd.DataFrame(standings_DF['data']['standings'])
# Out:
#                                                  team  \
# 0   {'id': '382', 'uid': 's:600~t:382', 'location'...
# 1   {'id': '360', 'uid': 's:600~t:360', 'location'...
# 2   {'id': '364', 'uid': 's:600~t:364', 'location'...
# 3   {'id': '363', 'uid': 's:600~t:363', 'location'...
# 4   {'id': '375', 'uid': 's:600~t:375', 'location'...
# 5   {'id': '371', 'uid': 's:600~t:371', 'location'...
# 6   {'id': '367', 'uid': 's:600~t:367', 'location'...
# 7   {'id': '359', 'uid': 's:600~t:359', 'location'...
# 8   {'id': '357', 'uid': 's:600~t:357', 'location'...
# 9   {'id': '368', 'uid': 's:600~t:368', 'location'...
# 10  {'id': '362', 'uid': 's:600~t:362', 'location'...
# 11  {'id': '361', 'uid': 's:600~t:361', 'location'...
# 12  {'id': '380', 'uid': 's:600~t:380', 'location'...
# 13  {'id': '384', 'uid': 's:600~t:384', 'location'...
# 14  {'id': '376', 'uid': 's:600~t:376', 'location'...
# 15  {'id': '331', 'uid': 's:600~t:331', 'location'...
# ...

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['team'])
# Out:
#     id          uid         location             name abbreviation  \
# 0  382  s:600~t:382  Manchester City  Manchester City          MNC
#
#        displayName shortDisplayName  isActive  \
# 0  Manchester City         Man City      True
#
#                                                logos
# 0  {'href': 'https://a.espncdn.com/i/teamlogos/so...

# %%
pd.DataFrame(standings_DF['data']['standings']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   team    20 non-null     object
#  1   note    10 non-null     object
#  2   stats   20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['stats'])
# Out:
#                  name       displayName shortDisplayName  \
# 0                wins              Wins                W
# 1              losses            Losses                L
# 2                ties             Draws                D
# 3         gamesPlayed      Games Played               GP
# 4           pointsFor         Goals For                F
# 5       pointsAgainst     Goals Against                A
# 6              points            Points                P
# 7          rankChange       Rank Change      Rank Change
# 8                rank              Rank             Rank
# 9   pointDifferential   Goal Difference               GD
# 10         deductions  Point Deductions       Deductions
# 11                ppg   Points Per Game              PPG
# 12         All Splits           Overall             OVER
#
#                        description abbreviation               type  value  \
# 0   Team's current Win-Loss record            W               wins   27.0
# ...

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['team']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1 non-null      object
#  1   uid               1 non-null      object
#  2   location          1 non-null      object
#  3   name              1 non-null      object
#  4   abbreviation      1 non-null      object
#  5   displayName       1 non-null      object
#  6   shortDisplayName  1 non-null      object
#  7   isActive          1 non-null      bool
#  8   logos             1 non-null      object
# dtypes: bool(1), object(8)
# memory usage: 193.0+ bytes

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['team']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1 non-null      object
#  1   uid               1 non-null      object
#  2   location          1 non-null      object
#  3   name              1 non-null      object
#  4   abbreviation      1 non-null      object
#  5   displayName       1 non-null      object
#  6   shortDisplayName  1 non-null      object
#  7   isActive          1 non-null      bool
#  8   logos             1 non-null      object
# dtypes: bool(1), object(8)
# memory usage: 193.0+ bytes

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['team'])
# Out:
#     id          uid         location             name abbreviation  \
# 0  382  s:600~t:382  Manchester City  Manchester City          MNC
#
#        displayName shortDisplayName  isActive  \
# 0  Manchester City         Man City      True
#
#                                                logos
# 0  {'href': 'https://a.espncdn.com/i/teamlogos/so...

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['stats'])
# Out:
#                  name       displayName shortDisplayName  \
# 0                wins              Wins                W
# 1              losses            Losses                L
# 2                ties             Draws                D
# 3         gamesPlayed      Games Played               GP
# 4           pointsFor         Goals For                F
# 5       pointsAgainst     Goals Against                A
# 6              points            Points                P
# 7          rankChange       Rank Change      Rank Change
# 8                rank              Rank             Rank
# 9   pointDifferential   Goal Difference               GD
# 10         deductions  Point Deductions       Deductions
# 11                ppg   Points Per Game              PPG
# 12         All Splits           Overall             OVER
#
#                        description abbreviation               type  value  \
# 0   Team's current Win-Loss record            W               wins   27.0
# ...

# %%
pd.DataFrame(standings_DF['data']['standings'][0]['stats'])
# Out:
#                  name       displayName shortDisplayName  \
# 0                wins              Wins                W
# 1              losses            Losses                L
# 2                ties             Draws                D
# 3         gamesPlayed      Games Played               GP
# 4           pointsFor         Goals For                F
# 5       pointsAgainst     Goals Against                A
# 6              points            Points                P
# 7          rankChange       Rank Change      Rank Change
# 8                rank              Rank             Rank
# 9   pointDifferential   Goal Difference               GD
# 10         deductions  Point Deductions       Deductions
# 11                ppg   Points Per Game              PPG
# 12         All Splits           Overall             OVER
#
#                        description abbreviation               type  value  \
# 0   Team's current Win-Loss record            W               wins   27.0
# ...

# %%
pd.DataFrame(standings_DF['data']['standings'][0:20])
# Out:
#                                                  team  \
# 0   {'id': '382', 'uid': 's:600~t:382', 'location'...
# 1   {'id': '360', 'uid': 's:600~t:360', 'location'...
# 2   {'id': '364', 'uid': 's:600~t:364', 'location'...
# 3   {'id': '363', 'uid': 's:600~t:363', 'location'...
# 4   {'id': '375', 'uid': 's:600~t:375', 'location'...
# 5   {'id': '371', 'uid': 's:600~t:371', 'location'...
# 6   {'id': '367', 'uid': 's:600~t:367', 'location'...
# 7   {'id': '359', 'uid': 's:600~t:359', 'location'...
# 8   {'id': '357', 'uid': 's:600~t:357', 'location'...
# 9   {'id': '368', 'uid': 's:600~t:368', 'location'...
# 10  {'id': '362', 'uid': 's:600~t:362', 'location'...
# 11  {'id': '361', 'uid': 's:600~t:361', 'location'...
# 12  {'id': '380', 'uid': 's:600~t:380', 'location'...
# 13  {'id': '384', 'uid': 's:600~t:384', 'location'...
# 14  {'id': '376', 'uid': 's:600~t:376', 'location'...
# 15  {'id': '331', 'uid': 's:600~t:331', 'location'...
# ...

# %%
standings_DF['data']
# Out:
# abbreviation                                                  Prem
# name                                        English Premier League
# season                                                        2020
# seasonDisplay                                            2020-2021
# standings        [{'team': {'id': '382', 'uid': 's:600~t:382', ...
# Name: data, dtype: object

# %%
standings_DF['data']['standings']
# Out:
# [{'team': {'id': '382',
#    'uid': 's:600~t:382',
#    'location': 'Manchester City',
#    'name': 'Manchester City',
#    'abbreviation': 'MNC',
#    'displayName': 'Manchester City',
#    'shortDisplayName': 'Man City',
#    'isActive': True,
#    'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'default'],
#      'lastUpdated': '2019-05-08T16:07Z'}]},
#   'note': {'color': '#81D6AC', 'description': 'Champions League', 'rank': 1},
#   'stats': [{'name': 'wins',
#     'displayName': 'Wins',
#     'shortDisplayName': 'W',
#     'description': "Team's current Win-Loss record",
#     'abbreviation': 'W',
#     'type': 'wins',
#     'value': 27,
#     'displayValue': '27'},
#    {'name': 'losses',
#     'displayName': 'Losses',
#     'shortDisplayName': 'L',
#     'description': 'Losses',
#     'abbreviation': 'L',
#     'type': 'losses',
#     'value': 6,
# ...

# %%
standings_DF['data']['standings'][0:20]
# Out:
# [{'team': {'id': '382',
#    'uid': 's:600~t:382',
#    'location': 'Manchester City',
#    'name': 'Manchester City',
#    'abbreviation': 'MNC',
#    'displayName': 'Manchester City',
#    'shortDisplayName': 'Man City',
#    'isActive': True,
#    'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#      'width': 500,
#      'height': 500,
#      'alt': '',
#      'rel': ['full', 'default'],
#      'lastUpdated': '2019-05-08T16:07Z'}]},
#   'note': {'color': '#81D6AC', 'description': 'Champions League', 'rank': 1},
#   'stats': [{'name': 'wins',
#     'displayName': 'Wins',
#     'shortDisplayName': 'W',
#     'description': "Team's current Win-Loss record",
#     'abbreviation': 'W',
#     'type': 'wins',
#     'value': 27,
#     'displayValue': '27'},
#    {'name': 'losses',
#     'displayName': 'Losses',
#     'shortDisplayName': 'L',
#     'description': 'Losses',
#     'abbreviation': 'L',
#     'type': 'losses',
#     'value': 6,
# ...

# %%
data_DF = pd.DataFrame(standings_DF['data']['standings'][0:20])
data_DF
# Out:
#                                                  team  \
# 0   {'id': '382', 'uid': 's:600~t:382', 'location'...
# 1   {'id': '360', 'uid': 's:600~t:360', 'location'...
# 2   {'id': '364', 'uid': 's:600~t:364', 'location'...
# 3   {'id': '363', 'uid': 's:600~t:363', 'location'...
# 4   {'id': '375', 'uid': 's:600~t:375', 'location'...
# 5   {'id': '371', 'uid': 's:600~t:371', 'location'...
# 6   {'id': '367', 'uid': 's:600~t:367', 'location'...
# 7   {'id': '359', 'uid': 's:600~t:359', 'location'...
# 8   {'id': '357', 'uid': 's:600~t:357', 'location'...
# 9   {'id': '368', 'uid': 's:600~t:368', 'location'...
# 10  {'id': '362', 'uid': 's:600~t:362', 'location'...
# 11  {'id': '361', 'uid': 's:600~t:361', 'location'...
# 12  {'id': '380', 'uid': 's:600~t:380', 'location'...
# 13  {'id': '384', 'uid': 's:600~t:384', 'location'...
# 14  {'id': '376', 'uid': 's:600~t:376', 'location'...
# 15  {'id': '331', 'uid': 's:600~t:331', 'location'...
# ...

# %%
data_DF['note'][0]
# Out:
# {'color': '#81D6AC', 'description': 'Champions League', 'rank': 1}

# %%
data_DF['team'][0]
# Out:
# {'id': '382',
#  'uid': 's:600~t:382',
#  'location': 'Manchester City',
#  'name': 'Manchester City',
#  'abbreviation': 'MNC',
#  'displayName': 'Manchester City',
#  'shortDisplayName': 'Man City',
#  'isActive': True,
#  'logos': [{'href': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#    'width': 500,
#    'height': 500,
#    'alt': '',
#    'rel': ['full', 'default'],
#    'lastUpdated': '2019-05-08T16:07Z'}]}

# %%
data_DF['stats'][0]
# Out:
# [{'name': 'wins',
#   'displayName': 'Wins',
#   'shortDisplayName': 'W',
#   'description': "Team's current Win-Loss record",
#   'abbreviation': 'W',
#   'type': 'wins',
#   'value': 27,
#   'displayValue': '27'},
#  {'name': 'losses',
#   'displayName': 'Losses',
#   'shortDisplayName': 'L',
#   'description': 'Losses',
#   'abbreviation': 'L',
#   'type': 'losses',
#   'value': 6,
#   'displayValue': '6'},
#  {'name': 'ties',
#   'displayName': 'Draws',
#   'shortDisplayName': 'D',
#   'description': 'Draws',
#   'abbreviation': 'D',
#   'type': 'ties',
#   'value': 5,
#   'displayValue': '5'},
#  {'name': 'gamesPlayed',
#   'displayName': 'Games Played',
#   'shortDisplayName': 'GP',
#   'description': 'Games Played',
#   'abbreviation': 'GP',
#   'type': 'gamesplayed',
#   'value': 38,
#   'displayValue': '38'},
#  {'name': 'pointsFor',
#   'displayName': 'Goals For',
#   'shortDisplayName': 'F',
#   'description': 'Goals For',
#   'abbreviation': 'F',
#   'type': 'pointsfor',
# ...

# %%
TeamNames = pd.DataFrame(data_DF['team'][0:20])
TeamNames
# Out:
#                                                  team
# 0   {'id': '382', 'uid': 's:600~t:382', 'location'...
# 1   {'id': '360', 'uid': 's:600~t:360', 'location'...
# 2   {'id': '364', 'uid': 's:600~t:364', 'location'...
# 3   {'id': '363', 'uid': 's:600~t:363', 'location'...
# 4   {'id': '375', 'uid': 's:600~t:375', 'location'...
# 5   {'id': '371', 'uid': 's:600~t:371', 'location'...
# 6   {'id': '367', 'uid': 's:600~t:367', 'location'...
# 7   {'id': '359', 'uid': 's:600~t:359', 'location'...
# 8   {'id': '357', 'uid': 's:600~t:357', 'location'...
# 9   {'id': '368', 'uid': 's:600~t:368', 'location'...
# 10  {'id': '362', 'uid': 's:600~t:362', 'location'...
# 11  {'id': '361', 'uid': 's:600~t:361', 'location'...
# 12  {'id': '380', 'uid': 's:600~t:380', 'location'...
# 13  {'id': '384', 'uid': 's:600~t:384', 'location'...
# 14  {'id': '376', 'uid': 's:600~t:376', 'location'...
# 15  {'id': '331', 'uid': 's:600~t:331', 'location'...
# ...

# %%
TeamNames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   team    20 non-null     object
# dtypes: object(1)
# memory usage: 288.0+ bytes

# %%
TeamNames['team'][0:20]
# Out:
# 0     {'id': '382', 'uid': 's:600~t:382', 'location'...
# 1     {'id': '360', 'uid': 's:600~t:360', 'location'...
# 2     {'id': '364', 'uid': 's:600~t:364', 'location'...
# 3     {'id': '363', 'uid': 's:600~t:363', 'location'...
# 4     {'id': '375', 'uid': 's:600~t:375', 'location'...
# 5     {'id': '371', 'uid': 's:600~t:371', 'location'...
# 6     {'id': '367', 'uid': 's:600~t:367', 'location'...
# 7     {'id': '359', 'uid': 's:600~t:359', 'location'...
# 8     {'id': '357', 'uid': 's:600~t:357', 'location'...
# 9     {'id': '368', 'uid': 's:600~t:368', 'location'...
# 10    {'id': '362', 'uid': 's:600~t:362', 'location'...
# 11    {'id': '361', 'uid': 's:600~t:361', 'location'...
# 12    {'id': '380', 'uid': 's:600~t:380', 'location'...
# 13    {'id': '384', 'uid': 's:600~t:384', 'location'...
# 14    {'id': '376', 'uid': 's:600~t:376', 'location'...
# 15    {'id': '331', 'uid': 's:600~t:331', 'location'...
# 16    {'id': '379', 'uid': 's:600~t:379', 'location'...
# ...

# %%
TeamNames['team']
# Out:
# 0     {'id': '382', 'uid': 's:600~t:382', 'location'...
# 1     {'id': '360', 'uid': 's:600~t:360', 'location'...
# 2     {'id': '364', 'uid': 's:600~t:364', 'location'...
# 3     {'id': '363', 'uid': 's:600~t:363', 'location'...
# 4     {'id': '375', 'uid': 's:600~t:375', 'location'...
# 5     {'id': '371', 'uid': 's:600~t:371', 'location'...
# 6     {'id': '367', 'uid': 's:600~t:367', 'location'...
# 7     {'id': '359', 'uid': 's:600~t:359', 'location'...
# 8     {'id': '357', 'uid': 's:600~t:357', 'location'...
# 9     {'id': '368', 'uid': 's:600~t:368', 'location'...
# 10    {'id': '362', 'uid': 's:600~t:362', 'location'...
# 11    {'id': '361', 'uid': 's:600~t:361', 'location'...
# 12    {'id': '380', 'uid': 's:600~t:380', 'location'...
# 13    {'id': '384', 'uid': 's:600~t:384', 'location'...
# 14    {'id': '376', 'uid': 's:600~t:376', 'location'...
# 15    {'id': '331', 'uid': 's:600~t:331', 'location'...
# 16    {'id': '379', 'uid': 's:600~t:379', 'location'...
# ...

# %%
PremNames = []
for index,row in TeamNames.iterrows():
    PremNames = [TeamNames['team'][index]['name']]
print(PremNames)
# Out:
# ['Sheffield United']

# %%
PremNames = [d.get('name') for d in TeamNames.team]
PremNames
# Out:
# ['Manchester City',
#  'Manchester United',
#  'Liverpool',
#  'Chelsea',
#  'Leicester City',
#  'West Ham United',
#  'Tottenham Hotspur',
#  'Arsenal',
#  'Leeds United',
#  'Everton',
#  'Aston Villa',
#  'Newcastle United',
#  'Wolverhampton Wanderers',
#  'Crystal Palace',
#  'Southampton',
#  'Brighton & Hove Albion',
#  'Burnley',
#  'Fulham',
#  'West Bromwich Albion',
#  'Sheffield United']

# %%
PremNames = {'Team Name': [d.get('name') for d in TeamNames.team]}
PremNames_DF= pd.DataFrame(PremNames)
PremNames_DF
# Out:
#                   Team Name
# 0           Manchester City
# 1         Manchester United
# 2                 Liverpool
# 3                   Chelsea
# 4            Leicester City
# 5           West Ham United
# 6         Tottenham Hotspur
# 7                   Arsenal
# 8              Leeds United
# 9                   Everton
# 10              Aston Villa
# 11         Newcastle United
# 12  Wolverhampton Wanderers
# 13           Crystal Palace
# 14              Southampton
# 15   Brighton & Hove Albion
# 16                  Burnley
# 17                   Fulham
# 18     West Bromwich Albion
# 19         Sheffield United

# %%
data_DF['stats']
# Out:
# 0     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 1     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 2     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 3     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 4     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 5     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 6     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 7     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 8     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 9     [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 10    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 11    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 12    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 13    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 14    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 15    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 16    [{'name': 'wins', 'displayName': 'Wins', 'shor...
# ...

# %%
TeamStats = pd.DataFrame(data_DF['stats'])
TeamStats
# Out:
#                                                 stats
# 0   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 1   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 2   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 3   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 4   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 5   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 6   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 7   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 8   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 9   [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 10  [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 11  [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 12  [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 13  [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 14  [{'name': 'wins', 'displayName': 'Wins', 'shor...
# 15  [{'name': 'wins', 'displayName': 'Wins', 'shor...
# ...
